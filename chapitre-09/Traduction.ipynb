# %% [markdown]
# # Traduction d'un modèle sémantique

# %% [markdown]
# ## Installation de la librairie
# https://pypi.org/project/semantic-link-labs/

# %%
# %pip install semantic-link-labs
# Out:
# StatementMeta(, de41e1aa-06ae-4191-9c21-05730f9341e3, 7, Finished, Available, Finished)
# Collecting semantic-link-labs
#   Downloading semantic_link_labs-0.5.0-py3-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 6.0 MB/s eta 0:00:00
# Collecting semantic-link-sempy>=0.7.5 (from semantic-link-labs)
#   Downloading semantic_link_sempy-0.7.6-py3-none-any.whl (3.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 71.0 MB/s eta 0:00:0000:01
# Collecting anytree (from semantic-link-labs)
#   Downloading anytree-2.12.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 21.1 MB/s eta 0:00:00
# Requirement already satisfied: powerbiclient in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-labs) (3.1.1)
# Requirement already satisfied: clr-loader>=0.2.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (0.2.6)
# Requirement already satisfied: graphviz>=0.20.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (0.20.1)
# Requirement already satisfied: pyarrow>=12.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (12.0.1)
# Requirement already satisfied: pythonnet>=3.0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (3.0.1)
# Requirement already satisfied: scikit-learn>=1.3.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (1.3.0)
# Requirement already satisfied: setuptools>=68.2.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (68.2.2)
# Requirement already satisfied: tqdm>=4.66.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from semantic-link-sempy>=0.7.5->semantic-link-labs) (4.66.1)
# Requirement already satisfied: six in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from anytree->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (8.0.7)
# Requirement already satisfied: jupyter-ui-poll>=0.1.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (0.2.2)
# Requirement already satisfied: msal>=1.8.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (1.24.1)
# Requirement already satisfied: requests>=2.25.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (2.31.0)
# Requirement already satisfied: pandas in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (2.0.3)
# Requirement already satisfied: pyspark in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from powerbiclient->semantic-link-labs) (3.4.1.5.3.20230713)
# Requirement already satisfied: cffi>=1.13 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from clr-loader>=0.2.6->semantic-link-sempy>=0.7.5->semantic-link-labs) (1.16.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.26.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.12.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.9)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (2.8.0)
# Requirement already satisfied: cryptography<44,>=0.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from msal>=1.8.0->powerbiclient->semantic-link-labs) (41.0.5)
# Requirement already satisfied: numpy>=1.16.6 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyarrow>=12.0.1->semantic-link-sempy>=0.7.5->semantic-link-labs) (1.24.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (1.26.17)
# Requirement already satisfied: certifi>=2017.4.17 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from requests>=2.25.1->powerbiclient->semantic-link-labs) (2023.7.22)
# Requirement already satisfied: scipy>=1.5.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.3.0->semantic-link-sempy>=0.7.5->semantic-link-labs) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.3.0->semantic-link-sempy>=0.7.5->semantic-link-labs) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from scikit-learn>=1.3.0->semantic-link-sempy>=0.7.5->semantic-link-labs) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pandas->powerbiclient->semantic-link-labs) (2023.3)
# Requirement already satisfied: py4j==0.10.9.7 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pyspark->powerbiclient->semantic-link-labs) (0.10.9.7)
# Requirement already satisfied: pycparser in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from cffi>=1.13->clr-loader>=0.2.6->semantic-link-sempy>=0.7.5->semantic-link-labs) (2.21)
# Requirement already satisfied: comm>=0.1.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (8.5.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.4.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.5.8)
# Requirement already satisfied: packaging in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (23.2)
# Requirement already satisfied: psutil in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (6.3.3)
# Requirement already satisfied: backcall in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.0)
# Requirement already satisfied: decorator in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.19.1)
# Requirement already satisfied: pickleshare in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.16.1)
# Requirement already satisfied: stack-data in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (3.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.7.0)
# Requirement already satisfied: wcwidth in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.8)
# Requirement already satisfied: executing>=1.2.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (2.4.0)
# Requirement already satisfied: pure-eval in /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->powerbiclient->semantic-link-labs) (0.2.2)
# Installing collected packages: anytree, semantic-link-sempy, semantic-link-labs
#   Attempting uninstall: semantic-link-sempy
#     Found existing installation: semantic-link-sempy 0.7.2
#     Not uninstalling semantic-link-sempy at /home/trusted-service-user/cluster-env/trident_env/lib/python3.10/site-packages, outside environment /nfs4/pyenv-a19ee870-b2cd-468f-9f43-b8e50a54cf17
#     Can't uninstall 'semantic-link-sempy'. No files were found to uninstall.
# Successfully installed anytree-2.12.1 semantic-link-labs-0.5.0 semantic-link-sempy-0.7.6
#
# [notice] A new release of pip is available: 23.1.2 -> 24.1.2
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Warning: PySpark kernel has been restarted to use updated packages.

# %% [markdown]
# ## Connection au modèle sémantique

# %%
import sempy_labs as labs
from sempy_labs.tom import connect_semantic_model
dataset = 'Regional Sales Sample'   # Report Name
workspace = 'Global Analysis'       # Workspace Name
with connect_semantic_model(dataset=dataset, readonly=True, workspace=workspace) as tom:
    for t in tom.model.Tables:
        print(t.Name)
# Out:
# StatementMeta(, de41e1aa-06ae-4191-9c21-05730f9341e3, 9, Finished, Available, Finished)
# Accounts
# Industries
# Opportunities
# Owners
# Products
# Opportunity Forecast Adjustment
# Opportunity Calendar
# Contacts
# Territories
# Campaigns

# %% [markdown]
# ## Ajout d'une traduction au modèle sémantique
# XMLA Endpoint Read & Write requis

# %%
with connect_semantic_model(dataset=dataset, readonly=False, workspace=workspace) as tom:
    tom.add_translation(language = 'fr-FR')
# Out:
# StatementMeta(, de41e1aa-06ae-4191-9c21-05730f9341e3, 10, Finished, Available, Finished)

# %% [markdown]
# Exemple de traduction de la table Products en Produit :

# %%
with connect_semantic_model(dataset=dataset, readonly=False, workspace=workspace) as tom:
    tom.set_translation(object = tom.model.Tables['Products'], language = 'fr-FR', property = 'Name', value = 'Produit')

# %% [markdown]
# ## Traduction de tous le modèle sémantique

# %%
labs.translate_semantic_model (dataset=dataset, workspace=workspace, languages= 'fr-FR')
# Out:
# StatementMeta(, de41e1aa-06ae-4191-9c21-05730f9341e3, 11, Finished, Available, Finished)
# ⌛ Translating Names...
# ⌛ Translating into the 'fr-FR' language...
# 🟢 Translation 'Comptes' set for the 'fr-FR' language on the 'Accounts' table.
# 🟢 Translation 'Nom du compte' set on the 'Account Name' column within the Accounts' table.
# 🟢 Translation 'État ou province' set on the 'State or Province' column within the Accounts' table.
# 🟢 Translation 'Numéro de compte' set on the 'Account Number' column within the Accounts' table.
# 🟢 Translation 'Industries' set for the 'fr-FR' language on the 'Industries' table.
# 🟢 Translation 'Industrie' set on the 'Industry' column within the Industries' table.
# 🟢 Translation 'Possibilités' set for the 'fr-FR' language on the 'Opportunities' table.
# 🟢 Translation 'Processus d’achat' set on the 'Purchase Process' column within the Opportunities' table.
# 🟢 Translation 'Identification du décideur' set on the 'Decision Maker Identified' column within the Opportunities' table.
# 🟢 Translation 'Statut' set on the 'Status' column within the Opportunities' table.
# 🟢 Translation 'Étape de vente' set on the 'Sales Stage' column within the Opportunities' table.
# 🟢 Translation 'Semaines Ouvert' set on the 'Weeks Open' column within the Opportunities' table.
# 🟢 Translation 'DaysToClose' set on the 'DaysToClose' column within the Opportunities' table.
# 🟢 Translation 'Rabais' set on the 'Discount' column within the Opportunities' table.
# 🟢 Translation 'Probabilité' set on the 'Probability' column within the Opportunities' table.
# 🟢 Translation 'Notation' set on the 'Rating' column within the Opportunities' table.
# 🟢 Translation 'Jours restants dans le pipeline' set on the 'Days Remaining In Pipeline' column within the Opportunities' table.
# 🟢 Translation 'Opportunité créée le' set on the 'Opportunity Created On' column within the Opportunities' table.
# 🟢 Translation 'CloseDate' set on the 'CloseDate' column within the Opportunities' table.
# 🟢 Translation 'Nombre de jours restants dans le pipeline (emplacements)' set on the 'Days Remaining In Pipeline (bins)' column within the Opportunities' table.
# 🟢 Translation 'Chiffre d’affaires gagné' set on the 'Revenue Won' column within the Opportunities' table.
# 🟢 Translation 'Revenus en cours de réalisation' set on the 'Revenue In Pipeline' column within the Opportunities' table.
# 🟢 Translation '% de prévision' set on the 'Forecast %' column within the Opportunities' table.
# 🟢 Translation 'Prévision' set on the 'Forecast' column within the Opportunities' table.
# 🟢 Translation 'Nombre d’opportunités en cours' set on the 'Opportunity Count In Pipeline' column within the Opportunities' table.
# 🟢 Translation 'Nombre d’opportunités' set on the 'Opportunity Count' column within the Opportunities' table.
# 🟢 Translation 'Nombre de victoires' set on the 'Count of Won' column within the Opportunities' table.
# 🟢 Translation 'Comte des perdus' set on the 'Count of Lost' column within the Opportunities' table.
# 🟢 Translation 'Fermer %' set on the 'Close %' column within the Opportunities' table.
# 🟢 Translation 'Chiffre d’affaires Ouvert' set on the 'Revenue Open' column within the Opportunities' table.
# 🟢 Translation 'Chiffre d’affaires gagné Taille moyenne des transactions' set on the 'Revenue Won Average Deal Size' column within the Opportunities' table.
# 🟢 Translation 'Prévisions par ratio gains/pertes' set on the 'Forecast by Win/Loss Ratio' column within the Opportunities' table.
# 🟢 Translation 'Propriétaire' set for the 'fr-FR' language on the 'Owners' table.
# 🟢 Translation 'Propriétaire' set on the 'Owner' column within the Owners' table.
# 🟢 Translation 'Gérant' set on the 'Manager' column within the Owners' table.
# 🟢 Translation 'Objectif Rev' set on the 'Rev Goal' column within the Owners' table.
# 🟢 Translation 'Produits' set for the 'fr-FR' language on the 'Products' table.
# 🟢 Translation 'Produit' set on the 'Product' column within the Products' table.
# 🟢 Translation 'Catégorie de produit' set on the 'Product Category' column within the Products' table.
# 🟢 Translation 'Fcst adj slicer alt text' set on the 'Fcst adj slicer alt text' column within the Opportunity Forecast Adjustment' table.
# 🟢 Translation 'Calendrier des opportunités' set for the 'fr-FR' language on the 'Opportunity Calendar' table.
# 🟢 Translation 'Date' set on the 'Date' column within the Opportunity Calendar' table.
# 🟢 Translation 'ANNÉE' set on the 'YEAR' column within the Opportunity Calendar' table.
# 🟢 Translation 'MOIS' set on the 'MONTH' column within the Opportunity Calendar' table.
# 🟢 Translation 'ANNÉE MOIS' set on the 'YEAR MONTH' column within the Opportunity Calendar' table.
# 🟢 Translation 'SEMAINE DE L’ANNÉE' set on the 'YEAR WEEK' column within the Opportunity Calendar' table.
# 🟢 Translation 'SEMAINE' set on the 'WEEK' column within the Opportunity Calendar' table.
# 🟢 Translation 'SEMAINE RELATIVE' set on the 'RELATIVE WEEK' column within the Opportunity Calendar' table.
# 🟢 Translation 'JOURNÉE RELATIVE' set on the 'RELATIVE DAY' column within the Opportunity Calendar' table.
# 🟢 Translation 'PÉRIODE RELATIVE 07 JOURS' set on the 'RELATIVE 07 DAY PERIOD' column within the Opportunity Calendar' table.
# 🟢 Translation 'PÉRIODE RELATIVE DE 30 JOURS' set on the 'RELATIVE 30 DAY PERIOD' column within the Opportunity Calendar' table.
# 🟢 Translation 'MOIS RELATIF' set on the 'RELATIVE MONTH' column within the Opportunity Calendar' table.
# 🟢 Translation 'Contacts' set for the 'fr-FR' language on the 'Contacts' table.
# 🟢 Translation 'Contact' set on the 'Contact' column within the Contacts' table.
# 🟢 Translation 'Titre du poste' set on the 'Job Title' column within the Contacts' table.
# 🟢 Translation 'Territoires' set for the 'fr-FR' language on the 'Territories' table.
# 🟢 Translation 'État ou province' set on the 'State Or Province' column within the Territories' table.
# 🟢 Translation 'Campagnes' set for the 'fr-FR' language on the 'Campaigns' table.
# 🟢 Translation 'Type de campagne' set on the 'Campaign Type' column within the Campaigns' table.
# 🟢 Translation 'Campagne' set on the 'Campaign' column within the Campaigns' table.
# ⌛ Translating Descriptions...
# ⌛ Translating into the 'fr-FR' language...
# ⌛ Translating Display Folders...
# ⌛ Translating into the 'fr-FR' language...
